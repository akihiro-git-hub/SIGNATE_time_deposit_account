# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import gridspec
import seaborn as sns
import plotly.graph_objects as go
import plotly.express as px
from sklearn.model_selection import KFold
from sklearn.metrics import log_loss, accuracy_score
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb
from scipy.stats import zscore
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv('C:\\Users\\odoru\\SIGNATE_time_deposit_account\\train.csv')
test = pd.read_csv('C:\\Users\\odoru\\SIGNATE_time_deposit_account\\test.csv')
submit = pd.read_csv('C:\\Users\\odoru\\SIGNATE_time_deposit_account\\head_submit_sample.csv')

# %%
test.replace({'job': {'unknown':'blue-collar'}}, inplace=True)

#score列の作成
train['score'] = np.zeros(train.shape[0])


#個人ローン
#学習データ
loan_none = train.loc[train['loan'] == 'no']
index = loan_none.index.values
index = list(index)

for i in index:
    train.iloc[i,18] = 1
    


#住宅ローン
housing_none = train.loc[train['housing'] == 'no']
index = housing_none.index.values
index = list(index)

score_values = housing_none['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    train.loc[train['housing']=='no','score'] = i



#債務不履行
default = train.loc[train['default'] == 'yes']


score_values = default['score'].values
score_values = score_values - 3
score_values = list(score_values)

for i in score_values:
    train.loc[train['default']=='yes','score'] = i





#経営者
management = train.loc[train['job'] == 'management']


score_values = management['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    train.loc[train['job']=='management','score'] = i
    


#管理者
admin = train.loc[train['job'] == 'admin.']


score_values = admin['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    train.loc[train['job']=='admin.','score'] = i
    



#学生
student = train.loc[train['job'] == 'student']


score_values = student['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    train.loc[train['job']=='student','score'] = i
    




#失業者
unemployed = train.loc[train['job'] == 'unemployed']


score_values = unemployed['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    train.loc[train['job']=='unemployed','score'] = i
    
train.loc[train['job'] == 'unemployed']




#定年退職者
retired = train.loc[train['job'] == 'retired']


score_values = retired['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    train.loc[train['job']=='retired','score'] = i

# %%
#テストデータ
#score列の作成
test['score'] = np.zeros(test.shape[0])

#個人ローン
loan_none = test.loc[test['loan'] == 'no']
index = loan_none.index.values
index = list(index)

for i in index:
    test.iloc[i,17] = 1



#住宅ローン
housing_none = test.loc[test['housing'] == 'no']

score_values = housing_none['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    test.loc[test['housing']=='no','score'] = i



#債務不履行
default = test.loc[test['default'] == 'yes']


score_values = default['score'].values
score_values = score_values - 3
score_values = list(score_values)

for i in score_values:
    test.loc[test['default']=='yes','score'] = i





#経営者
management = test.loc[test['job'] == 'management']


score_values = management['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    test.loc[test['job']=='management','score'] = i
    


#管理者
admin = test.loc[test['job'] == 'admin.']


score_values = admin['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    test.loc[test['job']=='admin.','score'] = i
    



#学生
student = test.loc[test['job'] == 'student']


score_values = student['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    test.loc[test['job']=='student','score'] = i
    




#失業者
unemployed = test.loc[test['job'] == 'unemployed']


score_values = unemployed['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    test.loc[test['job']=='unemployed','score'] = i
    



#定年退職者
retired = test.loc[test['job'] == 'retired']


score_values = retired['score'].values
score_values = score_values + 1
score_values = list(score_values)

for i in score_values:
    test.loc[test['job']=='retired','score'] = i

# %%
over_20 = train['age'].values
over_20 = over_20 - 20 


over_20_test = test['age'].values
over_20_test = over_20_test - 20 


an_income = over_20 * train['balance'].values


an_income_test = over_20_test * test['balance'].values

train['an_income'] = an_income
test['an_income'] = an_income_test

# %%
previous = train['previous'].values
duration = train['duration'].values
pre_total_duration = previous * duration
train['pre_total_duration'] = pre_total_duration


previous_test = test['previous'].values
duration_test = test['duration'].values
pre_total_duration_test = previous_test * duration_test
test['pre_total_duration'] = pre_total_duration_test

# %%
train_x = train.iloc[:,1:17]
train_x['score'] = train['score']
train_x['an_income'] = train['an_income']
train_x['pre_total_duration'] = train['pre_total_duration']
train_y = train['y']
test_x = test.iloc[:,1:]

# %%
train_x
# Out:
#        age           job  marital  education default  balance housing loan  \
# 0       31      services  married  secondary      no    12294     yes   no
# 1       29  entrepreneur   single   tertiary      no    43027      no   no
# 2       35    management  married   tertiary      no    12252     yes   no
# 3       31    technician  married  secondary      no    99121     yes  yes
# 4       48    unemployed  married    primary      no    42005     yes   no
# ...    ...           ...      ...        ...     ...      ...     ...  ...
# 27095   37   blue-collar  married  secondary      no    26661     yes   no
# 27096   35      services  married  secondary      no    42150     yes   no
# 27097   35      services  married    unknown      no    34531      no   no
# 27098   30        admin.   single  secondary      no    99621     yes   no
# 27099   34    management  married   tertiary      no     8657     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 0       cellular   21   nov       101         3    498         0    other
# 1       cellular   22   aug       158         2    702         0  unknown
# 2       cellular   11   nov       351         1    826         0  failure
# 3        unknown   16   may       658         2    120         0  failure
# 4      telephone    3   apr       177         1    273         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 27095   cellular   27   may       345         4    425         0  unknown
# 27096   cellular   27   may       121         1    719         0  unknown
# 27097   cellular   28   jun       177         2    121         0  unknown
# 27098   cellular   27   may       121         1    100         0  unknown
# 27099   cellular   27   may       345         2    321         0  unknown
#
#        score  an_income  pre_total_duration
# 0        1.0     135234                   0
# 1        2.0     387243                   0
# 2        2.0     183780                   0
# 3        0.0    1090331                   0
# 4        3.0    1176140                   0
# ...      ...        ...                 ...
# 27095    1.0     453237                   0
# 27096    1.0     632250                   0
# 27097    2.0     517965                   0
# 27098    2.0     996210                   0
# 27099    2.0     121198                   0
#
# [27100 rows x 19 columns]

# %%
cat_cols = ['job','marital','education','default','housing','loan','contact','month','poutcome']
#LabelEncording
for c in cat_cols:
    le = LabelEncoder()
    le.fit(train[c])
    train_x[c] = le.transform(train[c])
    test_x[c] = le.transform(test[c])

# %%
#cat_cols = ['education','housing','month','poutcome']

#TargetEncording
#TargetEncording用のfoldに分割してTargetEncordingする方法    
#for c in cat_cols:
    #学習データのカテゴリカル変数のカラムごとの変数とtargetをデータフレームとする。
    #data_tmp = pd.DataFrame({c:train_x[c], 'target': train_y})
    #データフレームのカラムの要素ごとの平均を取る
    #target_mean = data_tmp.groupby(c)['target'].mean()
    #訓練データフレームの平均をテストデータに入れる。
    #test_x.loc[:,c] = test_x[c].map(target_mean)
    
    #訓練データを入れるための空の箱を作る
    #tmp = np.repeat(np.nan, train_x.shape[0])
    
    
    #one of out holdで一つ一つのバリデーションに平均値を入れていく
    #kf =  KFold(n_splits=4, shuffle=True, random_state=71)
    #for idx_1, idx_2 in kf.split(train_x):
        
       #target_mean = data_tmp.iloc[idx_1].groupby(c)['target'].mean()
        
        #tmp[idx_2] = train_x[c].iloc[idx_2].map(target_mean)
        
    #train_x[c] = tmp

# %%
#hold out 法
kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x,va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y,va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx] 


scaler = StandardScaler()
scaler.fit_transform(train_x)
scaler.fit_transform(test_x)
# Out:
# array([[-0.14042776,  1.4454851 ,  1.45235137, ...,  0.6128679 ,
#          0.85068028,  1.47293149],
#        [ 0.1139091 ,  0.83693432, -0.30268259, ..., -0.93690313,
#          0.49385981, -0.14553211],
#        [-0.64910149,  0.83693432,  1.45235137, ..., -0.93690313,
#         -0.61015874, -0.14553211],
#        ...,
#        [-0.2675962 , -1.2929934 ,  1.45235137, ...,  0.6128679 ,
#          0.82701507, -0.14553211],
#        [-0.64910149,  1.4454851 ,  1.45235137, ..., -0.93690313,
#         -0.05915788, -0.14553211],
#        [-0.77626992,  0.22838354, -0.30268259, ...,  2.16263893,
#         -1.02849692, -0.14553211]])

# %%
d_train = xgb.DMatrix(tr_x, label=tr_y)
d_valid = xgb.DMatrix(va_x, label=va_y)

params = {'objective':'binary:logistic','silent':1, 'random_state':71, 'eta':0.1}

num_round = 500

watchilist = [(d_train,'train'),(d_valid,'eval')]

model = xgb.train(params,d_train, num_round, evals = watchilist, early_stopping_rounds=20 )

val_pred = model.predict(d_valid, ntree_limit = model.best_ntree_limit)

score = log_loss(va_y,val_pred)
print(score)
# Out:
# [10:49:00] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.06799	eval-error:0.07055
# Multiple eval metrics have been passed: 'eval-error' will be used for early stopping.
#
# Will train until eval-error hasn't improved in 20 rounds.
# [1]	train-error:0.06824	eval-error:0.07041
# [2]	train-error:0.06760	eval-error:0.07070
# [3]	train-error:0.06819	eval-error:0.07026
# [4]	train-error:0.06716	eval-error:0.07011
# [5]	train-error:0.06770	eval-error:0.06922
# [6]	train-error:0.06731	eval-error:0.06937
# [7]	train-error:0.06750	eval-error:0.06937
# [8]	train-error:0.06741	eval-error:0.06967
# [9]	train-error:0.06735	eval-error:0.06922
# [10]	train-error:0.06701	eval-error:0.06864
# [11]	train-error:0.06691	eval-error:0.06834
# [12]	train-error:0.06677	eval-error:0.06804
# [13]	train-error:0.06701	eval-error:0.06760
# [14]	train-error:0.06696	eval-error:0.06731
# [15]	train-error:0.06701	eval-error:0.06701
# [16]	train-error:0.06657	eval-error:0.06686
# [17]	train-error:0.06686	eval-error:0.06716
# [18]	train-error:0.06677	eval-error:0.06672
# [19]	train-error:0.06662	eval-error:0.06716
# [20]	train-error:0.06657	eval-error:0.06672
# [21]	train-error:0.06657	eval-error:0.06672
# [22]	train-error:0.06637	eval-error:0.06657
# [23]	train-error:0.06657	eval-error:0.06657
# [24]	train-error:0.06632	eval-error:0.06657
# [25]	train-error:0.06608	eval-error:0.06672
# [26]	train-error:0.06613	eval-error:0.06686
# [27]	train-error:0.06603	eval-error:0.06731
# [28]	train-error:0.06583	eval-error:0.06701
# [29]	train-error:0.06568	eval-error:0.06716
# [30]	train-error:0.06573	eval-error:0.06672
# [31]	train-error:0.06544	eval-error:0.06627
# [32]	train-error:0.06534	eval-error:0.06598
# [33]	train-error:0.06524	eval-error:0.06627
# [34]	train-error:0.06504	eval-error:0.06627
# [35]	train-error:0.06509	eval-error:0.06583
# [36]	train-error:0.06475	eval-error:0.06598
# [37]	train-error:0.06460	eval-error:0.06598
# [38]	train-error:0.06455	eval-error:0.06553
# [39]	train-error:0.06445	eval-error:0.06539
# [40]	train-error:0.06426	eval-error:0.06539
# [41]	train-error:0.06401	eval-error:0.06553
# [42]	train-error:0.06386	eval-error:0.06524
# [43]	train-error:0.06357	eval-error:0.06553
# [44]	train-error:0.06312	eval-error:0.06524
# [45]	train-error:0.06298	eval-error:0.06553
# [46]	train-error:0.06308	eval-error:0.06568
# [47]	train-error:0.06288	eval-error:0.06568
# [48]	train-error:0.06273	eval-error:0.06583
# [49]	train-error:0.06278	eval-error:0.06583
# [50]	train-error:0.06258	eval-error:0.06583
# [51]	train-error:0.06234	eval-error:0.06583
# [52]	train-error:0.06180	eval-error:0.06583
# [53]	train-error:0.06170	eval-error:0.06568
# [54]	train-error:0.06150	eval-error:0.06583
# [55]	train-error:0.06130	eval-error:0.06598
# [56]	train-error:0.06125	eval-error:0.06553
# [57]	train-error:0.06125	eval-error:0.06539
# [58]	train-error:0.06135	eval-error:0.06539
# [59]	train-error:0.06145	eval-error:0.06553
# [60]	train-error:0.06091	eval-error:0.06509
# [61]	train-error:0.06066	eval-error:0.06539
# [62]	train-error:0.06052	eval-error:0.06539
# [63]	train-error:0.06047	eval-error:0.06568
# [64]	train-error:0.06052	eval-error:0.06583
# [65]	train-error:0.06042	eval-error:0.06598
# [66]	train-error:0.06022	eval-error:0.06553
# [67]	train-error:0.06003	eval-error:0.06509
# [68]	train-error:0.05988	eval-error:0.06524
# [69]	train-error:0.06012	eval-error:0.06495
# [70]	train-error:0.05998	eval-error:0.06524
# [71]	train-error:0.05988	eval-error:0.06539
# [72]	train-error:0.05963	eval-error:0.06539
# [73]	train-error:0.05953	eval-error:0.06509
# [74]	train-error:0.05924	eval-error:0.06524
# [75]	train-error:0.05914	eval-error:0.06524
# [76]	train-error:0.05914	eval-error:0.06539
# [77]	train-error:0.05889	eval-error:0.06539
# [78]	train-error:0.05880	eval-error:0.06539
# [79]	train-error:0.05874	eval-error:0.06539
# [80]	train-error:0.05840	eval-error:0.06583
# [81]	train-error:0.05811	eval-error:0.06553
# [82]	train-error:0.05806	eval-error:0.06553
# [83]	train-error:0.05796	eval-error:0.06553
# [84]	train-error:0.05781	eval-error:0.06568
# [85]	train-error:0.05776	eval-error:0.06568
# [86]	train-error:0.05761	eval-error:0.06568
# [87]	train-error:0.05766	eval-error:0.06539
# [88]	train-error:0.05737	eval-error:0.06553
# [89]	train-error:0.05727	eval-error:0.06553
# Stopping. Best iteration:
# [69]	train-error:0.06012	eval-error:0.06495
#
# 0.19668036931294028

# %%
fig = plt.figure()

fpr,tpr,thresholds = roc_curve(va_y,val_pred)
auc_score = roc_auc_score(va_y,val_pred)

plt.plot(fpr,tpr)
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title(f'ROC curve/AUC Score : {auc_score}')

plt.grid(True)

# %%
# 重要度の上位を出力する
fscore = model.get_score(importance_type ='total_gain')
fscore = sorted([ (k, v ) for k, v in fscore.items()], key = lambda tpl: [1], reverse=True)
print('xgboost immportance')
print(fscore[:5])
# Out:
# xgboost immportance
# [('previous', 1255.8277371390002), ('housing', 2288.093957472001), ('month', 2717.5519102619996), ('poutcome', 3099.5697776170005), ('education', 365.1954982590002)]

# %%
#データのｙを求める
d_test = xgb.DMatrix(test_x)


test_pred = model.predict(d_test, ntree_limit=model.best_ntree_limit)

# %%
id = test['id']
test_pred = pd.Series(test_pred)
pred = test_pred

submit = pd.concat([id,pred], axis=1)
submit.columns = ['id', 'y']
submit
# Out:
#           id         y
# 0          0  0.718612
# 1          1  0.087817
# 2          2  0.022825
# 3          3  0.003575
# 4          4  0.042037
# ...      ...       ...
# 18045  18045  0.010842
# 18046  18046  0.012852
# 18047  18047  0.105116
# 18048  18048  0.004204
# 18049  18049  0.095402
#
# [18050 rows x 2 columns]

# %%
submit.to_csv('xgboost_best.csv',index=False,header=False)

# %%
train_x.to_csv('train_x_xgboost.csv',index=False)
train_y.to_csv('train_y_xgboost.csv',index=False)
test_x.to_csv('test_x_xgboost.csv',index=False)

# %% [markdown]
# # ハイパーパラメータのチューニング

# %%
kf = KFold(n_splits=4, shuffle=True, random_state=71)
tr_idx, va_idx = list(kf.split(train_x))[0]
tr_x, va_x = train_x.iloc[tr_idx], train_x.iloc[va_idx]
tr_y, va_y = train_y.iloc[tr_idx], train_y.iloc[va_idx]

# %%
import xgboost as xgb


#モデルの定義
class Model:
    
    def __init__(self,params=None):
        self.params = None
        if params is None:
            self.params = {}
        else :
            self.params = params
            
    def fit(self, tr_x, tr_y, va_x, va_y):
        params = {'booster':'gbtree',
          'objective':'binary:logistic',
          'silent':1,
          'random_state':71,
          'eta':,}
        params.update(self.params)
        num_round = 10
        dtrain = xgb.DMatrix(tr_x, label=tr_y)
        dvalid = xgb.DMatrix(va_x, label=va_y)
        watchlist = [(dtrain, 'train'), (dvalid, 'eval')]
        self.model = xgb.train(params, d_train, num_round, evals =watchilist)
        
        
    def predict(self, x):
        data = xgb.DMatrix(x)
        pred = self.model.predict(data)
        return pred

# %%
from hyperopt import hp

from hyperopt import fmin, tpe, hp , STATUS_OK, Trials
from sklearn.metrics import log_loss

def score(params) :
    
    params['max_depth'] = int(params['max_depth'])
    
    model = Model(params)
    model.fit(tr_x, tr_y, va_x, va_y)
    va_pred = model.predict(va_x)
    score = log_loss(va_y, va_pred)
    print(f'params: {params}, logloss : {score : .4f}')
    
    history.append((params, score))
    
    return {'loss': score, 'status': STATUS_OK}



space = {
    'max_depth': hp.quniform('max_depth', 3, 9, 1),
}



max_evals = 10
trials = Trials()
history = []
fmin(score, space, algo=tpe.suggest, trials=trials, max_evals = max_evals)


history = sorted(history, key=lambda tpl: tpl[1])
best = history[0]
print(f'best params : {best[0]}, score:{best[1]:.4f}')
# Out:
# [10:20:31] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.06799	eval-error:0.07055
#
# [1]	train-error:0.06824	eval-error:0.07041
#
# [2]	train-error:0.06790	eval-error:0.07055
#
# [3]	train-error:0.06804	eval-error:0.07070
#
# [4]	train-error:0.06760	eval-error:0.07026
#
# [5]	train-error:0.06785	eval-error:0.07055
#
# [6]	train-error:0.06829	eval-error:0.07011
#
# [7]	train-error:0.06814	eval-error:0.06996
#
# [8]	train-error:0.06735	eval-error:0.07041
#
# [9]	train-error:0.06780	eval-error:0.06952
#
# params: {'max_depth': 6}, logloss :  0.4395
# [10:20:31] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.06622	eval-error:0.07026
#
# [1]	train-error:0.06622	eval-error:0.07011
#
# [2]	train-error:0.06622	eval-error:0.06996
#
# [3]	train-error:0.06632	eval-error:0.06996
#
# [4]	train-error:0.06652	eval-error:0.06982
#
# [5]	train-error:0.06632	eval-error:0.07011
#
# [6]	train-error:0.06598	eval-error:0.06982
#
# [7]	train-error:0.06603	eval-error:0.06982
#
# [8]	train-error:0.06627	eval-error:0.06996
#
# [9]	train-error:0.06593	eval-error:0.06996
#
# params: {'max_depth': 7}, logloss :  0.4388
# [10:20:31] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.06440	eval-error:0.07173
#
# [1]	train-error:0.06431	eval-error:0.07085
#
# [2]	train-error:0.06426	eval-error:0.07129
#
# [3]	train-error:0.06445	eval-error:0.07055
#
# [4]	train-error:0.06416	eval-error:0.07055
#
# [5]	train-error:0.06470	eval-error:0.07026
#
# [6]	train-error:0.06440	eval-error:0.07041
#
# [7]	train-error:0.06406	eval-error:0.07011
#
# [8]	train-error:0.06352	eval-error:0.06982
#
# [9]	train-error:0.06386	eval-error:0.06982
#
# params: {'max_depth': 9}, logloss :  0.4382
# [10:20:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.06622	eval-error:0.07026
#
# [1]	train-error:0.06622	eval-error:0.07011
#
# [2]	train-error:0.06622	eval-error:0.06996
#
# [3]	train-error:0.06632	eval-error:0.06996
#
# [4]	train-error:0.06652	eval-error:0.06982
#
# [5]	train-error:0.06632	eval-error:0.07011
#
# [6]	train-error:0.06598	eval-error:0.06982
#
# [7]	train-error:0.06603	eval-error:0.06982
#
# [8]	train-error:0.06627	eval-error:0.06996
#
# [9]	train-error:0.06593	eval-error:0.06996
#
# params: {'max_depth': 7}, logloss :  0.4388
# [10:20:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.06563	eval-error:0.07129
#
# [1]	train-error:0.06558	eval-error:0.07100
#
# [2]	train-error:0.06534	eval-error:0.07085
#
# [3]	train-error:0.06563	eval-error:0.07055
#
# [4]	train-error:0.06563	eval-error:0.07041
#
# [5]	train-error:0.06539	eval-error:0.07026
#
# [6]	train-error:0.06495	eval-error:0.07070
#
# [7]	train-error:0.06519	eval-error:0.07026
#
# [8]	train-error:0.06514	eval-error:0.07026
#
# [9]	train-error:0.06480	eval-error:0.06952
#
# params: {'max_depth': 8}, logloss :  0.4385
# [10:20:32] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.07223	eval-error:0.06790
#
# [1]	train-error:0.07228	eval-error:0.06790
#
# [2]	train-error:0.07233	eval-error:0.06790
#
# [3]	train-error:0.07233	eval-error:0.06790
#
# [4]	train-error:0.07233	eval-error:0.06790
#
# [5]	train-error:0.07233	eval-error:0.06790
#
# [6]	train-error:0.07233	eval-error:0.06790
#
# [7]	train-error:0.07233	eval-error:0.06790
#
# [8]	train-error:0.07233	eval-error:0.06790
#
# [9]	train-error:0.07233	eval-error:0.06790
#
# params: {'max_depth': 4}, logloss :  0.4411
# [10:20:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.07001	eval-error:0.07070
#
# [1]	train-error:0.07001	eval-error:0.07070
#
# [2]	train-error:0.06996	eval-error:0.07041
#
# [3]	train-error:0.07001	eval-error:0.07041
#
# [4]	train-error:0.06991	eval-error:0.07011
#
# [5]	train-error:0.07006	eval-error:0.06967
#
# [6]	train-error:0.07026	eval-error:0.06982
#
# [7]	train-error:0.07006	eval-error:0.06982
#
# [8]	train-error:0.07026	eval-error:0.06952
#
# [9]	train-error:0.06972	eval-error:0.06922
#
# params: {'max_depth': 5}, logloss :  0.4403
# [10:20:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.06440	eval-error:0.07173
#
# [1]	train-error:0.06431	eval-error:0.07085
#
# [2]	train-error:0.06426	eval-error:0.07129
#
# [3]	train-error:0.06445	eval-error:0.07055
#
# [4]	train-error:0.06416	eval-error:0.07055
#
# [5]	train-error:0.06470	eval-error:0.07026
#
# [6]	train-error:0.06440	eval-error:0.07041
#
# [7]	train-error:0.06406	eval-error:0.07011
#
# [8]	train-error:0.06352	eval-error:0.06982
#
# [9]	train-error:0.06386	eval-error:0.06982
#
# params: {'max_depth': 9}, logloss :  0.4382
# [10:20:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.06799	eval-error:0.07055
#
# [1]	train-error:0.06824	eval-error:0.07041
#
# [2]	train-error:0.06790	eval-error:0.07055
#
# [3]	train-error:0.06804	eval-error:0.07070
#
# [4]	train-error:0.06760	eval-error:0.07026
#
# [5]	train-error:0.06785	eval-error:0.07055
#
# [6]	train-error:0.06829	eval-error:0.07011
#
# [7]	train-error:0.06814	eval-error:0.06996
#
# [8]	train-error:0.06735	eval-error:0.07041
#
# [9]	train-error:0.06780	eval-error:0.06952
#
# params: {'max_depth': 6}, logloss :  0.4395
# [10:20:33] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.1.0\src\learner.cc:480:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]	train-error:0.07233	eval-error:0.06790
#
# [1]	train-error:0.07233	eval-error:0.06790
#
# [2]	train-error:0.07233	eval-error:0.06790
# [3]	train-error:0.07233	eval-error:0.06790
#
# [4]	train-error:0.07233	eval-error:0.06790
#
# [5]	train-error:0.07233	eval-error:0.06790
#
# [6]	train-error:0.07233	eval-error:0.06790
#
# [7]	train-error:0.07233	eval-error:0.06790
#
# [8]	train-error:0.07233	eval-error:0.06790
#
# [9]	train-error:0.07233	eval-error:0.06790
#
# params: {'max_depth': 3}, logloss :  0.4430
# 100%|███████████████████████████████████████████████| 10/10 [00:02<00:00,  3.57trial/s, best loss: 0.43815661122438215]
# best params : {'max_depth': 9}, score:0.4382

# %%
# Out:
# []
